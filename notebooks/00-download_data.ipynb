# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/day.csv")
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
dicionario = pd.DataFrame([
    {
        "variavel":"instant",
        "descricao":"Índice de registro",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel":"dteday",
        "descricao":"Data",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel":"season",
        "descricao":"Estação do ano",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel":"yr",
        "descricao":"Ano",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel":"mnth",
        "descricao":"Mês",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel":"holiday",
        "descricao":"Se o dia é feriado ou não",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel":"weekday",
        "descricao":"Dia da semana",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel":"workingday",
        "descricao":"Se o dia não é fim de semana e nem feriado",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel":"weathersit",
        "descricao":"Clima",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel":"temp",
        "descricao":"Temperatura normalizada em Celsius",
        "tipo":"quantitativa",
        "subtipo":"contínua"
    },{
        "variavel":"atemp",
        "descricao":"Temperatura de sensação normalizada em Celsius",
        "tipo":"quantitativa",
        "subtipo":"contínua"
    },{
        "variavel":"hum",
        "descricao":"Umidade do ar",
        "tipo":"quantitiva",
        "subtipo":"contínua"
    },{
        "variavel":"windspeed",
        "descricao":"Velocidade do vento",
        "tipo":"quantitiva",
        "subtipo":"contínua"
    },{
        "variavel":"casual",
        "descricao":"Contagem de usuários casuais",
        "tipo":"quantitiva",
        "subtipo":"discreta"
    },{
        "variavel":"registered",
        "descricao":"Contagem de usuários registrados",
        "tipo":"quantitiva",
        "subtipo":"discreta"
    },{
        "variavel":"cnt",
        "descricao":"Contagem total de bicicletas alugadas, incluindo casuais e registradas",
        "tipo":"quantitiva",
        "subtipo":"discreta"
    }
])
dicionario
# Out:
#       variavel                                          descricao  \
# 0      instant                                 Índice de registro
# 1       dteday                                               Data
# 2       season                                     Estação do ano
# 3           yr                                                Ano
# 4         mnth                                                Mês
# 5      holiday                          Se o dia é feriado ou não
# 6      weekday                                      Dia da semana
# 7   workingday         Se o dia não é fim de semana e nem feriado
# 8   weathersit                                              Clima
# 9         temp                 Temperatura normalizada em Celsius
# 10       atemp     Temperatura de sensação normalizada em Celsius
# 11         hum                                      Umidade do ar
# 12   windspeed                                Velocidade do vento
# ...

# %%
dicionario.to_csv('../data/external/dictionary.csv', index=False)
